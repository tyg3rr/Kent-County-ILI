# %%
import pandas as pd
from make_google_trends_dataset import make_google_trends_dataset
from make_weather_dataset import make_weather_dataset
from surveillance_datasets import make_incidence_dataset, make_syndromic_dataset
from get_aqi_dataset import get_aqi_dataset

# %%
dd = make_google_trends_dataset()\
    .join(make_weather_dataset(),how='inner')\
    .join(make_incidence_dataset(),how='inner')\
    .join(make_syndromic_dataset(),how='inner')\
    .join(get_aqi_dataset(),how='inner')
# Out:
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations

# %%
dd
# Out:
#          GS_cold  GS_cough  GS_fever  GS_flu  ...   CO  Ozone  PM10  PM25
# epiweek                                       ...
# 200503      3016       331      1059     714  ...  3.0    NaN   8.0  32.0
# 200503      3016       331      1059     714  ...  3.0    NaN   8.0  32.0
# 200503      3016       331      1059     714  ...  3.0    NaN   8.0  32.0
# 200503      3016       331      1059     714  ...  3.0    NaN   8.0  32.0
# 200503      3016       331      1059     714  ...  3.0    NaN   8.0  32.0
# ...          ...       ...       ...     ...  ...  ...    ...   ...   ...
# 201951      4113      1245      1537    1639  ...  6.0   19.0  31.0  54.0
# 201951      4113      1245      1537    1639  ...  6.0   19.0  31.0  54.0
# 201951      4113      1245      1537    1639  ...  6.0   19.0  31.0  54.0
# 201951      4113      1245      1537    1639  ...  6.0   19.0  31.0  54.0
# 201951      4113      1245      1537    1639  ...  6.0   19.0  31.0  54.0
#
# [5285 rows x 18 columns]

# %%
dd.to_csv('raw_dataset.csv')

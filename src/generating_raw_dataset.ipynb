# %%
import pandas as pd
from utils.make_google_trends_dataset import make_google_trends_dataset
from utils.make_weather_dataset import make_weather_dataset
from utils.surveillance_datasets import make_incidence_dataset, make_syndromic_dataset
from utils.get_aqi_dataset import get_aqi_dataset

# %%
dd = make_google_trends_dataset()\
    .join(make_weather_dataset(),how='inner')\
    .join(make_incidence_dataset(),how='inner')\
    .join(make_syndromic_dataset(),how='inner')\
    .join(get_aqi_dataset(),how='inner')
# Out:
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# Retrying temporarily failed request in 1s (url=http://www.ncdc.noaa.gov/cdo-web/api/v2/data, params={'datasetid': 'GHCND', 'stationid': ['GHCND:USW00094860'], 'datatypeid': ['TMIN', 'TMAX', 'TAVG', 'PRCP', 'AWND', 'SNOW'], 'startdate': datetime.date(2018, 1, 1), 'enddate': datetime.date(2018, 12, 31), 'units': 'standard', 'offset': 2001, 'limit': 1000}, error='Request failed: https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&stationid=GHCND:USW00094860&datatypeid=TMIN&datatypeid=TMAX&datatypeid=TAVG&datatypeid=PRCP&datatypeid=AWND&datatypeid=SNOW&startdate=2018-01-01&enddate=2018-12-31&units=standard&offset=2001&limit=1000 (status_code=503)')
# No lookup list found for stations

# %%
dd
# Out:
#          GS_cold  GS_cough  GS_fever  GS_flu  AWND  PRCP  SNOW  TAVG  TMAX  \
# epiweek
# 200503      3010       336      1058     721   9.0   0.0   0.0  12.0  15.0
# 200503      3010       336      1058     721  10.0   0.0   0.0   9.0  13.0
# 200503      3010       336      1058     721  13.0   0.0   0.0   8.0  16.0
# 200503      3010       336      1058     721  16.0   0.0   3.0  23.0  31.0
# 200503      3010       336      1058     721  10.0   0.0   0.0  16.0  18.0
# ...          ...       ...       ...     ...   ...   ...   ...   ...   ...
# 201951      4177      1267      1551    1665  10.0   0.0   0.0  19.0  33.0
# 201951      4177      1267      1551    1665   9.0   0.0   0.0  32.0  36.0
# 201951      4177      1267      1551    1665   9.0   0.0   0.0  32.0  36.0
# 201951      4177      1267      1551    1665   8.0   0.0   0.0  33.0  46.0
# 201951      4177      1267      1551    1665   8.0   0.0   0.0  33.0  46.0
#
#          TMIN cases  visits  Overall AQI Value Main Pollutant   CO  Ozone  \
# epiweek
# 200503    8.0   326       1               32.0          PM2.5  3.0    NaN
# 200503    4.0   326       1               32.0          PM2.5  3.0    NaN
# 200503    0.0   326       1               32.0          PM2.5  3.0    NaN
# 200503   15.0   326       1               32.0          PM2.5  3.0    NaN
# 200503   14.0   326       1               32.0          PM2.5  3.0    NaN
# ...       ...   ...     ...                ...            ...  ...    ...
# 201951   11.0  1638      54               40.0          PM2.5  6.0   19.0
# 201951   27.0  1638      54               40.0          PM2.5  6.0   19.0
# 201951   27.0  1638      54               40.0          PM2.5  6.0   19.0
# 201951   26.0  1638      54               40.0          PM2.5  6.0   19.0
# 201951   26.0  1638      54               40.0          PM2.5  6.0   19.0
#
#          PM10  PM25
# epiweek
# 200503    8.0  32.0
# 200503    8.0  32.0
# 200503    8.0  32.0
# 200503    8.0  32.0
# 200503    8.0  32.0
# ...       ...   ...
# 201951   31.0  54.0
# 201951   31.0  54.0
# 201951   31.0  54.0
# 201951   31.0  54.0
# 201951   31.0  54.0
#
# [5285 rows x 18 columns]

# %%
dd.to_csv('data/raw_dataset.csv')

# %%
import pandas as pd
from utils.make_google_trends_dataset import make_google_trends_dataset
from utils.make_weather_dataset import make_weather_dataset
from utils.surveillance_datasets import make_incidence_dataset, make_syndromic_dataset
from utils.get_aqi_dataset import get_aqi_dataset

# %%
ggl = make_google_trends_dataset()
wthr = make_weather_dataset()
inc = make_incidence_dataset()
syn = make_syndromic_dataset()
aqi = get_aqi_dataset()
# Out:
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations
# No lookup list found for stations

# %%
dd = ggl.join(wthr.join(inc.join(aqi.join(syn, how='outer'),how='inner'),how='inner'),how='inner')

# %%
dd
# Out:
#          GS_cold  GS_cough  GS_fever  GS_flu       AWND      PRCP      SNOW  \
# epiweek
# 200452      3105       415      1023     741   9.714286  0.000000  0.000000
# 200501      2936       456      1047     817   8.428571  0.142857  1.142857
# 200502      2816       414      1048     707  11.142857  0.285714  0.428571
# 200503      3074       342      1057     720  12.142857  0.142857  2.142857
# 200504      3188       389      1062     782   7.285714  0.000000  0.000000
# ...          ...       ...       ...     ...        ...       ...       ...
# 201951      4146      1258      1553    1637   8.857143  0.000000  0.285714
# 201951      4146      1258      1553    1637   8.857143  0.000000  0.285714
# 201952      4120      1446      1655    1897   9.142857  0.000000  0.000000
# 201952      4120      1446      1655    1897   9.142857  0.000000  0.000000
# 202001      4213      1463      1615    1952  15.333333  0.666667  1.666667
#
#               TAVG       TMAX       TMIN  ... Overall AQI Value  \
# epiweek                                   ...
# 200452   28.285714  36.571429  19.714286  ...              39.0
# 200501   28.428571  31.857143  24.285714  ...              51.0
# 200502   29.857143  36.000000  23.000000  ...              47.0
# 200503   12.571429  17.714286   7.000000  ...              32.0
# 200504   16.428571  26.857143   3.857143  ...              58.0
# ...            ...        ...        ...  ...               ...
# 201951   26.857143  33.714286  20.857143  ...              40.0
# 201951   26.857143  33.714286  20.857143  ...              40.0
# 201952   39.285714  49.142857  32.000000  ...              47.0
# 201952   39.285714  49.142857  32.000000  ...              47.0
# 202001   39.666667  45.333333  33.333333  ...              31.0
#
#          Main Pollutant    CO  Ozone  PM10  PM25  Days Good  Days Moderate  \
# epiweek
# 200452            PM2.5   5.0    NaN   NaN  39.0          1              0
# 200501            PM2.5   5.0    NaN   9.0  51.0          3              4
# 200502            PM2.5   5.0    NaN  11.0  47.0          3              4
# 200503            PM2.5   3.0    NaN   8.0  32.0          6              1
# 200504            PM2.5   6.0    NaN  22.0  64.0          3              4
# ...                 ...   ...    ...   ...   ...        ...            ...
# 201951            PM2.5   6.0   19.0  31.0  54.0          4              3
# 201951            PM2.5   6.0   19.0  31.0  54.0          4              3
# 201952            PM2.5  10.0   21.0  19.0  47.0          5              2
# 201952            PM2.5  10.0   21.0  19.0  47.0          5              2
# 202001            Ozone   5.0   23.0   NaN  22.0          3              0
#
#          Days Unhealthy  visits
# epiweek
# 200452                0     NaN
# 200501                0     NaN
# 200502                0     NaN
# 200503                0     1.0
# 200504                0     NaN
# ...                 ...     ...
# 201951                0    54.0
# 201951                0    54.0
# 201952                0     NaN
# 201952                0     NaN
# 202001                0     NaN
#
# [834 rows x 21 columns]

# %%
dd.to_csv('data/raw_dataset.csv')
